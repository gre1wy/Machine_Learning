# %%
import nbformat

path = r"D:\University\semestr_7\Machine_Learning\lab1\Lab1_regression.ipynb"
nb = nbformat.read(open(path), as_version=4)
if "widgets" in nb["metadata"]:
    del nb["metadata"]["widgets"]
nbformat.write(nb, open(path, "w"))
print("Widgets metadata removed")
# Out:
# Widgets metadata removed
